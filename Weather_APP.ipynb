# %% [markdown]
# <a href="https://colab.research.google.com/github/Soumya1Kesharwani/LLM-10/blob/main/Weather_APP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
url="https://api.weatherapi.com/v1/current.json?key=e942dbeb75424295b4e94030242510&q=Mumbai"
response=requests.get(url)
data=response.json()
print(data["current"]["temp_c"])
# Out:
# 25.3
